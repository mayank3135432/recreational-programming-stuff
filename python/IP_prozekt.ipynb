# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dict={'name':['T-Series','Cocomelon','SET India','PewDiePie','MrBeast','Kids Diana Show','Like Nastya','WWE',
              'Zee Music Company','Vlad and Niki','5-Minute Crafts','Justin Bieber','Canal KondZilla','HYBE LABELS','Zee TV']
      ,'subs':[207487487,129426158,126511179,111430321,90402160,90203479,86706457,85703867,81502416,78407901,75641684,67542621,65356503,64101770,61310636]}
df=pd.DataFrame(dict)
print(df)
df.plot(x='name',y='subs',marker='o')
plt.xlabel('Channels')
plt.ylabel('Subscribers')
plt.show()
# Out:
#                  name       subs
# 0            T-Series  207487487
# 1           Cocomelon  129426158
# 2           SET India  126511179
# 3           PewDiePie  111430321
# 4             MrBeast   90402160
# 5     Kids Diana Show   90203479
# 6         Like Nastya   86706457
# 7                 WWE   85703867
# 8   Zee Music Company   81502416
# 9       Vlad and Niki   78407901
# 10    5-Minute Crafts   75641684
# 11      Justin Bieber   67542621
# 12    Canal KondZilla   65356503
# 13        HYBE LABELS   64101770
# 14             Zee TV   61310636

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dict={'name':['T-Series','Cocomelon','SET India','PewDiePie','MrBeast',
       'KidsDiana Show','Like Nastya','WWE','Zee Music Company'
              ,'Vlad and Niki','5-Minute Crafts','Justin Bieber'
              ,'Canal KondZilla','HYBE LABELS','Zee TV']
      ,'subs':[207487487,129426158,126511179,111430321,90402160,90203479
               ,86706457,85703867,81502416,78407901,75641684,67542621
               ,65356503,64101770,61310636]}
df=pd.DataFrame(dict)
print(df)
df.plot(kind='bar',x='name',y='subs')
plt.xlabel('Channels')
plt.ylabel('Subscribers')
plt.show()
# Out:
#                  name       subs
# 0            T-Series  207487487
# 1           Cocomelon  129426158
# 2           SET India  126511179
# 3           PewDiePie  111430321
# 4             MrBeast   90402160
# 5      KidsDiana Show   90203479
# 6         Like Nastya   86706457
# 7                 WWE   85703867
# 8   Zee Music Company   81502416
# 9       Vlad and Niki   78407901
# 10    5-Minute Crafts   75641684
# 11      Justin Bieber   67542621
# 12    Canal KondZilla   65356503
# 13        HYBE LABELS   64101770
# 14             Zee TV   61310636

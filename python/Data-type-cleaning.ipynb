# %%
import pandas as pd

# %%
df1 = pd.read_csv('/home/ateium/datasets/database.csv')
df1=df1[1000:2000]
df1.to_csv('significant_earthquakes.csv')

# %%
df1 = pd.read_csv('significant_earthquakes.csv')

# %%
df1.dtypes
# Out:
# Unnamed: 0                      int64
# Date                           object
# Time                           object
# Latitude                      float64
# Longitude                     float64
# Type                           object
# Depth                         float64
# Depth Error                   float64
# Depth Seismic Stations        float64
# Magnitude                     float64
# Magnitude Type                 object
# Magnitude Error               float64
# Magnitude Seismic Stations    float64
# Azimuthal Gap                 float64
# Horizontal Distance           float64
# Horizontal Error              float64
# Root Mean Square              float64
# ID                             object
# Source                         object
# Location Source                object
# Magnitude Source               object
# Status                         object
# dtype: object

# %%
print(df1.head())
# Out:
#    Unnamed: 0        Date      Time  Latitude  Longitude        Type  Depth  \
# 0        1000  07/29/1968  11:12:02   -22.531   -174.860  Earthquake   45.0
# 1        1001  07/29/1968  23:52:18    -0.291    133.409  Earthquake   20.0
# 2        1002  07/30/1968  20:38:43    -6.987    -80.544  Earthquake   31.8
# 3        1003  08/01/1968  00:14:17   -26.822   -177.090  Earthquake  127.2
# 4        1004  08/01/1968  20:19:22    16.316    122.067  Earthquake   25.0
#
#    Depth Error  Depth Seismic Stations  Magnitude  ...  \
# 0          NaN                     NaN        6.3  ...
# 1          NaN                     NaN        6.2  ...
# 2          NaN                     NaN        6.5  ...
# 3          NaN                     NaN        5.7  ...
# 4          NaN                     NaN        7.6  ...
#
#   Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                        NaN            NaN                  NaN
# ...

# %%
df2=df1.copy()
df2['Latitude']=df1['Latitude'].astype('int64')
df2.dtypes
# changing float to int causes LOSS OF DATA. This should not be commonly done
# Out:
# Unnamed: 0                      int64
# Date                           object
# Time                           object
# Latitude                        int64
# Longitude                     float64
# Type                           object
# Depth                         float64
# Depth Error                   float64
# Depth Seismic Stations        float64
# Magnitude                     float64
# Magnitude Type                 object
# Magnitude Error               float64
# Magnitude Seismic Stations    float64
# Azimuthal Gap                 float64
# Horizontal Distance           float64
# Horizontal Error              float64
# Root Mean Square              float64
# ID                             object
# Source                         object
# Location Source                object
# Magnitude Source               object
# Status                         object
# dtype: object

# %%
df1['Date'][1]-df1['Date'][0]
# trying to find number of days between the dates of first 2 records

# got TypeError since 'Date' field is str dtype instead of Date
# So lets convert it to Date !
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df1['Date'][1]-df1['Date'][0]
#       2 # trying to find number of days between the dates of first 2 records
#       3
#       4 # got
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
# Use to_datetime()
df1["Date"]=pd.to_datetime(df1["Date"], format= '%m/%d/%Y')

# %%
df1.dtypes
# Out:
# Unnamed: 0                             int64
# Date                          datetime64[ns]
# Time                                  object
# Latitude                             float64
# Longitude                            float64
# Type                                  object
# Depth                                float64
# Depth Error                          float64
# Depth Seismic Stations               float64
# Magnitude                            float64
# Magnitude Type                        object
# Magnitude Error                      float64
# Magnitude Seismic Stations           float64
# Azimuthal Gap                        float64
# Horizontal Distance                  float64
# Horizontal Error                     float64
# Root Mean Square                     float64
# ID                                    object
# Source                                object
# Location Source                       object
# Magnitude Source                      object
# ...

# %%
# let's try subtracting dates again
df1['Date'][1]-df1['Date'][0]

#both ttook place the same day
# Out:
# Timedelta('0 days 00:00:00')

# %%
df1.head(10)
# Out:
#    Unnamed: 0       Date      Time  Latitude  Longitude        Type  Depth  \
# 0        1000 1968-07-29  11:12:02   -22.531   -174.860  Earthquake   45.0
# 1        1001 1968-07-29  23:52:18    -0.291    133.409  Earthquake   20.0
# 2        1002 1968-07-30  20:38:43    -6.987    -80.544  Earthquake   31.8
# 3        1003 1968-08-01  00:14:17   -26.822   -177.090  Earthquake  127.2
# 4        1004 1968-08-01  20:19:22    16.316    122.067  Earthquake   25.0
# 5        1005 1968-08-02  13:30:25    27.579     60.979  Earthquake   67.4
# 6        1006 1968-08-02  14:06:43    16.519    -97.739  Earthquake   25.0
# 7        1007 1968-08-03  04:54:34    25.637    128.490  Earthquake   15.0
# 8        1008 1968-08-03  06:25:05    16.475    122.230  Earthquake   25.0
# 9        1009 1968-08-04  11:41:25     6.498    126.777  Earthquake  100.0
#
#    Depth Error  Depth Seismic Stations  Magnitude  ...  \
# 0          NaN                     NaN        6.3  ...
# ...

# %%
df1['Date'][1].day
# Out:
# 29

# %%
df1['Date'][1].month
# Out:
# 7

# %%
df1['Date'][1].year
# Out:
# 1968

# %%
# select_dtypes()

# %%
decimals=df1.select_dtypes('float')
decimals.head()
# Out:
#    Latitude  Longitude  Depth  Depth Error  Depth Seismic Stations  Magnitude  \
# 0   -22.531   -174.860   45.0          NaN                     NaN        6.3
# 1    -0.291    133.409   20.0          NaN                     NaN        6.2
# 2    -6.987    -80.544   31.8          NaN                     NaN        6.5
# 3   -26.822   -177.090  127.2          NaN                     NaN        5.7
# 4    16.316    122.067   25.0          NaN                     NaN        7.6
#
#    Magnitude Error  Magnitude Seismic Stations  Azimuthal Gap  \
# 0              NaN                         NaN            NaN
# 1              NaN                         NaN            NaN
# 2              NaN                         NaN            NaN
# 3              NaN                         NaN            NaN
# 4              NaN                         NaN            NaN
#
#    Horizontal Distance  Horizontal Error  Root Mean Square
# 0                  NaN               NaN               NaN
# ...

# %%
number_data = df1.select_dtypes(exclude = 'object')
number_data.head()
# Out:
#    Unnamed: 0       Date  Latitude  Longitude  Depth  Depth Error  \
# 0        1000 1968-07-29   -22.531   -174.860   45.0          NaN
# 1        1001 1968-07-29    -0.291    133.409   20.0          NaN
# 2        1002 1968-07-30    -6.987    -80.544   31.8          NaN
# 3        1003 1968-08-01   -26.822   -177.090  127.2          NaN
# 4        1004 1968-08-01    16.316    122.067   25.0          NaN
#
#    Depth Seismic Stations  Magnitude  Magnitude Error  \
# 0                     NaN        6.3              NaN
# 1                     NaN        6.2              NaN
# 2                     NaN        6.5              NaN
# 3                     NaN        5.7              NaN
# 4                     NaN        7.6              NaN
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# ...

# %%
## CHANGING dataTypes WHILE IMPORTING DATA

# %%
dtypes_dict={"Depth":"object","Time":"Date"}
# dtypes_dict={"Depth":"object"}

# %%
df3=pd.read_csv('significant_earthquakes.csv',dtype=dtypes_dict)
df3.dtypes

# /usr/lib/python3.11/site-packages/pandas/util/_decorators.py:211
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df3=pd.read_csv('significant_earthquakes.csv',dtype=dtypes_dict)
#       2 df3.dtypes
#
# File /usr/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /usr/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  1000 non-null   int64
#  1   Date                        1000 non-null   object
#  2   Time                        1000 non-null   object
#  3   Latitude                    1000 non-null   float64
#  4   Longitude                   1000 non-null   float64
#  5   Type                        1000 non-null   object
#  6   Depth                       1000 non-null   object
#  7   Depth Error                 4 non-null      float64
#  8   Depth Seismic Stations      6 non-null      float64
#  9   Magnitude                   1000 non-null   float64
#  10  Magnitude Type              1000 non-null   object
#  11  Magnitude Error             3 non-null      float64
#  12  Magnitude Seismic Stations  6 non-null      float64
# ...

# %%
# category dtype :
#    category is a dtype that can be used for categorical data
dict_types = {"Type":"category",
              "Status":"category",
              "Source":"category",
              "Location Source":"category",
              "Magnitude Source":"category",
              "Magnitude Type":"category"
             }
df4 = pd.read_csv('significant_earthquakes.csv',dtype=dict_types,parse_dates=['Date','Time'])
#df4 = pd.read_csv('significant_earthquakes.csv',dtype=dict_types)
df4.dtypes
# Out:
# Unnamed: 0                             int64
# Date                          datetime64[ns]
# Time                          datetime64[ns]
# Latitude                             float64
# Longitude                            float64
# Type                                category
# Depth                                float64
# Depth Error                          float64
# Depth Seismic Stations               float64
# Magnitude                            float64
# Magnitude Type                      category
# Magnitude Error                      float64
# Magnitude Seismic Stations           float64
# Azimuthal Gap                        float64
# Horizontal Distance                  float64
# Horizontal Error                     float64
# Root Mean Square                     float64
# ID                                    object
# Source                              category
# Location Source                     category
# Magnitude Source                    category
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  1000 non-null   int64
#  1   Date                        1000 non-null   datetime64[ns]
#  2   Time                        1000 non-null   datetime64[ns]
#  3   Latitude                    1000 non-null   float64
#  4   Longitude                   1000 non-null   float64
#  5   Type                        1000 non-null   category
#  6   Depth                       1000 non-null   float64
#  7   Depth Error                 4 non-null      float64
#  8   Depth Seismic Stations      6 non-null      float64
#  9   Magnitude                   1000 non-null   float64
#  10  Magnitude Type              1000 non-null   category
#  11  Magnitude Error             3 non-null      float64
# ...

# %%
### MEMORY USAGE DROPS FROM 171 TO 131 KB

# %%
df4.describe()
# Out:
#         Unnamed: 0     Latitude    Longitude        Depth  Depth Error  \
# count  1000.000000  1000.000000  1000.000000  1000.000000      4.00000
# mean   1499.500000    10.880167    50.336599    69.302950     25.41675
# std     288.819436    29.335218   120.913876   116.591685     12.38650
# min    1000.000000   -63.398000  -179.972000     1.200000      6.83700
# 25%    1249.750000    -9.017750   -71.793250    20.000000     25.41675
# 50%    1499.500000     8.164500   123.131000    30.000000     31.61000
# 75%    1749.250000    38.936500   145.416250    56.700000     31.61000
# max    1999.000000    79.744000   179.279000   662.000000     31.61000
#
#        Depth Seismic Stations    Magnitude  Magnitude Error  \
# count                6.000000  1000.000000         3.000000
# mean                 7.500000     6.017780         0.272000
# std                  8.288546     0.436026         0.120578
# min                  0.000000     5.500000         0.187000
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  1000 non-null   int64
#  1   Date                        1000 non-null   datetime64[ns]
#  2   Time                        1000 non-null   datetime64[ns]
#  3   Latitude                    1000 non-null   float64
#  4   Longitude                   1000 non-null   float64
#  5   Type                        1000 non-null   category
#  6   Depth                       1000 non-null   float64
#  7   Depth Error                 4 non-null      float64
#  8   Depth Seismic Stations      6 non-null      float64
#  9   Magnitude                   1000 non-null   float64
#  10  Magnitude Type              1000 non-null   category
#  11  Magnitude Error             3 non-null      float64
# ...

# %% [markdown]
# ####

# %%
df4.head()
# Out:
#    Unnamed: 0       Date                Time  Latitude  Longitude        Type  \
# 0        1000 1968-07-29 2024-02-17 11:12:02   -22.531   -174.860  Earthquake
# 1        1001 1968-07-29 2024-02-17 23:52:18    -0.291    133.409  Earthquake
# 2        1002 1968-07-30 2024-02-17 20:38:43    -6.987    -80.544  Earthquake
# 3        1003 1968-08-01 2024-02-17 00:14:17   -26.822   -177.090  Earthquake
# 4        1004 1968-08-01 2024-02-17 20:19:22    16.316    122.067  Earthquake
#
#    Depth  Depth Error  Depth Seismic Stations  Magnitude  ...  \
# 0   45.0          NaN                     NaN        6.3  ...
# 1   20.0          NaN                     NaN        6.2  ...
# 2   31.8          NaN                     NaN        6.5  ...
# 3  127.2          NaN                     NaN        5.7  ...
# 4   25.0          NaN                     NaN        7.6  ...
#
#   Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# ...

# %%
df4.isna().sum()
# Out:
# Unnamed: 0                      0
# Date                            0
# Time                            0
# Latitude                        0
# Longitude                       0
# Type                            0
# Depth                           0
# Depth Error                   996
# Depth Seismic Stations        994
# Magnitude                       0
# Magnitude Type                  0
# Magnitude Error               997
# Magnitude Seismic Stations    994
# Azimuthal Gap                 994
# Horizontal Distance           995
# Horizontal Error              997
# Root Mean Square              994
# ID                              0
# Source                          0
# Location Source                 0
# Magnitude Source                0
# Status                          0
# dtype: int64
